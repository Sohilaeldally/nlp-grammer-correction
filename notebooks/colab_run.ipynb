# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip -o "/content/drive/MyDrive/NLP_projects/grammer_correction.zip" -d "/content/NLP_project"
# Out:
# Archive:  /content/drive/MyDrive/NLP_projects/grammer_correction.zip
#   inflating: /content/NLP_project/grammer_correction/app.py
#   inflating: /content/NLP_project/grammer_correction/requirements.txt
#   inflating: /content/NLP_project/grammer_correction/data/Grammer Correction.csv
#   inflating: /content/NLP_project/grammer_correction/notebooks/data_exploration.ipynb
#   inflating: /content/NLP_project/grammer_correction/src/dataset.py
#   inflating: /content/NLP_project/grammer_correction/src/inference.py
#   inflating: /content/NLP_project/grammer_correction/src/metrics.py
#   inflating: /content/NLP_project/grammer_correction/src/tempCodeRunnerFile.py
#   inflating: /content/NLP_project/grammer_correction/src/train.py
#   inflating: /content/NLP_project/grammer_correction/src/__pycache__/dataset.cpython-311.pyc
#   inflating: /content/NLP_project/grammer_correction/src/__pycache__/metrics.cpython-311.pyc

# %%
import sys
sys.path.append("/content/NLP_project/grammer_correction/src")

# %%
# !ls "/content/NLP_project/grammer_correction/src"
# Out:
# dataset.py    metrics.py   tempCodeRunnerFile.py
# inference.py  __pycache__  train.py

# %%
# !ls "/content/NLP_project/grammer_correction/data"
# Out:
# 'Grammer Correction.csv'

# %%
# !python "/content/NLP_project/grammer_correction/src/train.py"
# Out:
# 2025-12-19 21:24:22.456004: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766179462.475292    3032 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766179462.481146    3032 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766179462.497429    3032 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
